# %%
import requests
from bs4 import BeautifulSoup as BTS
import pandas as pd

# %%
ticker = '005930'

# %%
url = f'https://finance.naver.com/item/sise.naver?code={ticker}'

# %%
headers = {
    'user-agent': 'Mozilla/5.0'
}

# %%
res = requests.get(url=url, headers=headers)

# %%
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '<!--  global include -->\n\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\t<title>삼성전자 : Npay 증권</title>\n\t\n\t\n\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="Npay 증권" />\n\n\n\n\n\n\t\n\t\t<meta property="og:title" content="Npay 증권"/>\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t<meta property="og:url" content="https://finance.naver.com"/>\n\t\t<meta property="og:description" content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공"/>\n    \n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="Npay 증권"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n\n\n\n<link rel=\'stylesheet\' t
# ...

# %%
res.headers['content-type']
# Out:
# 'text/html;charset=EUC-KR'

# %%
soup = BTS(markup=res.text, features='html.parser')

# %% [markdown]
# - BeautifulSoup 객체는 select 메서드에 원하는 CSS Selector(선택자)를 지정하여 수집하려는 텍스트를 포함하고 있는 HTML elements를 빠르게 필터링할 수 있음

# %%
def get_price_daily(ticker, page=1):
    url = f'https://finance.naver.com/item/sise_day.naver'
    query = {'code': ticker, 'page': page}
    headers = {'user-agent': 'Mozilla/5.0'}

    res = requests.get(url=url, headers=headers, params=query)
    soup = BTS(markup=res.text, features='html.parser')

    items_1 = soup.select(selector='td.num:nth-child(2) > span.tah.p11')
    price = [item.text for item in items_1]

    items_2 = soup.select(selector='td[align="center"]:nth-child(1) > span.tah.p10')
    date = [item.text for item in items_2]

    df = pd.DataFrame(data={'date': date, 'price': price})

    return df

# %%
get_price_daily(ticker='005930')
# Out:
#          date    price
# 0  2026.03.24  189,700
# 1  2026.03.23  186,300
# 2  2026.03.20  199,400
# 3  2026.03.19  200,500
# 4  2026.03.18  208,500
# 5  2026.03.17  193,900
# 6  2026.03.16  188,700
# 7  2026.03.13  183,500
# 8  2026.03.12  187,900
# 9  2026.03.11  190,000

# %%
import time
from tqdm.notebook import tqdm

# %%
dfs = pd.DataFrame()
for page in tqdm(range(10)):
    page += 1
    df = get_price_daily(ticker = '005930', page = page)
    dfs = pd.concat(objs = [dfs, df], ignore_index = True)
    time.sleep(1)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
dfs
# Out:
#           date    price
# 0   2026.03.24  189,700
# 1   2026.03.23  186,300
# 2   2026.03.20  199,400
# 3   2026.03.19  200,500
# 4   2026.03.18  208,500
# ..         ...      ...
# 95  2025.10.31  107,500
# 96  2025.10.30  104,100
# 97  2025.10.29  100,500
# 98  2025.10.28   99,500
# 99  2025.10.27  102,000
#
# [100 rows x 2 columns]
